# %% [markdown]
# # Semana 2 – Sistema operativo Linux para aplicaciones científicas
#
# Nombre del estudiante:
# Usuario del cluster:
# Fecha:

# %% [markdown]
# ## Instrucciones
#
# Todos los comandos mostrados a continuación fueron ejecutados en la terminal
# del cluster institucional usando PuTTY.
# Este notebook funciona únicamente como documentación del trabajo realizado.

# %% [markdown]
# ## Ejercicio 1 – Organización del entorno de trabajo

# %% [markdown]
# ```bash
# $ pwd
# /home/usuario
#
# $ mkdir curso_modelamiento_geoquimico
# $ cd curso_modelamiento_geoquimico
# $ mkdir datos scripts resultados
#
# $ ls
# datos  scripts  resultados

# %% [markdown]
# ---
#
# **Comentario:**
# Esta estructura permite organizar datos, scripts y resultados de forma clara,
# facilitando el trabajo computacional en el cluster.

# %% [markdown]
# ## Ejercicio 2 – Creación y edición de archivos

# %% [markdown]
# ```bash
# $ nano README.txt
# $ cat README.txt

# %% [markdown]
# ---
#
# ## Ejercicio 3 – Tipos de archivo
#
# ```bash
# $ file ejemplo.txt
# ejemplo.txt: ASCII text

# %% [markdown]
# ---
#
# ## Ejercicio 4 – Compresión
#
# ```markdown
# ```bash
# $ tar -czf semana2_linux_apellido.tar.gz curso_modelamiento_geoquimico
# $ file semana2_linux_apellido.tar.gz

# %% [markdown]
# Reflexión final
#
# ¿Por qué es importante organizar el trabajo y comprimir resultados en
# computación científica?
